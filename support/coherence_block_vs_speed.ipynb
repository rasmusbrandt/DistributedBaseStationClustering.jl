# %% [markdown]
# ### Input

# %%
fc = 2e9 # GHz
Wc = 300e3 # kHz
# Out:
# 300000.0

# %% [markdown]
# ### Calculations

# %%
vs_kmh = 1:100 # km/h
vs = vs_kmh*(1e3/3600) # m/s

c = 300e6 # m/s
λ = c/fc # m

fds = vs/(λ*Wc)
Ls = 1./(2*fds);

# %% [markdown]
# ### Specific speeds

# %%
for s in [5, 10, 15, 30, 50, 70, 90]
    println("$s km/h: $(Ls[s]) symbols")
end
# Out:
# 5 km/h: 16200.0 symbols
# 10 km/h: 8100.0 symbols
# 15 km/h: 5399.999999999999 symbols
# 30 km/h: 2699.9999999999995 symbols
# 50 km/h: 1619.9999999999998 symbols
# 70 km/h: 1157.142857142857 symbols
# 90 km/h: 900.0 symbols

# %% [markdown]
# ### Plot

# %%
using PyPlot
semilogy(vs_kmh, Ls)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x113b9f550>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11490dd10>
