# %%
using CoordinatedPrecoding

# %%
I = 8; Kc = 4; N = 3; M = 10
geography_size = (10000., 10000.)
# MS_serving_BS_distance = 1000.
MS_serving_BS_distance = nothing

network =
    setup_random_large_scale_network(I, Kc, N, M,
        geography_size=geography_size,
        MS_serving_BS_distance=MS_serving_BS_distance)

draw_user_drop!(network)
plot_network_layout(network)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11d6c1d90>)
