# %%
require("../src/misc/partitions.jl")

# %%
Ks = 1:20
bell_numbers = [ bell_number(k) for k in Ks ]

using PyPlot
semilogy(Ks, bell_numbers, ".")
xlabel("Number of BSs"); ylabel("Number of partitions (Bell number)")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119c51dd0>)
# PyObject <matplotlib.text.Text object at 0x119d18a10>
